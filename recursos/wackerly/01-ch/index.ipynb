# %% [markdown]
# # Mathematical Statistics With Applications - Chapter 1. What Is Statistics?
# **Author:** Edgar Daniel Ocampo Ortiz. \
# **source:** Wackerly, D. D., Mendenhall, W., & Scheaffer, R. L. (2008). *Mathematical Statistics with Applications* (7th ed.). Thomson Brooks/Cole. \
# **Objective:** Answer statistical problems using math and python.
#
# ---
#
# ## Chapter Contents
# - Subject 1: Understand the concept of Statistics, its components and its reach and objective.
# - Subject 2: Identify the parts of a statistical experiment.
# - Subject 3: Visualize the objectives that can be stated when planning a statistical experiment.

# %% [markdown]
# ## Used libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from statistics import stdev
import seaborn as sns

plt.style.use("seaborn-v0_8-darkgrid")
plt.rcParams['text.usetex'] = True

np.random.seed(123)

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.1**
# #### **Statement:**
#
# For each of the following situations, identify the population of interest, the inferential objective, and how you might go about collecting a sample.
#
# 1. The National Highway Safety Council wants to estimate the proportion of automobile tires with unsafe tread among all tires manufactured by a specific company during the current production year.
#
# 2. A political scientist wants to determine whether a majority of adult residents of a state favor a unicameral legislature.
#
# 3. A medical scientist wants to estimate the average length of time until the recurrence of a certain disease.
#
# 4. An electrical engineer wants to determine whether the average length of life of transistors of a certain type is greater than 500 hours.
#
# 5. A university researcher wants to estimate the proportion of U.S. citizens from "Generation X" who are interested in starting their own business.
#
# 6. For more than a century, normal body temperature for humans has been accepted to be 98.6 Fahrenheit. Is it really? Researchers want to estimate the average temperature of healthy adults in the United States.
#
# 7. A city engineer wants to estimate the average weekly water consumption for single-family dwelling units in the city.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:** \
# We identify the 3 parts necessary for our solution, *population of interest*, *the inferential objective*, *idea on collecting sample from population*.
#
#
# 1. The population of interest is all the tires fabricated by the specific company for this specific production year. The inferential objective is to predict the total number of tires with unsafe tread manufactured during the current production year. A sample could be collected by taking random tires from the assembly line and testing the safety of the tread.
#
# 2. The population of interest is adult residents of a state. The inferential objective is to determine wether a majority of the population is in favor of an unicameral legislature. To collect a sample there should be brigades of people conducting door to door pools, or cellphone calls by area registration or ads asking for an answer to the poll for social media users that live in that state.
#
# 3. The population of interest would be the patients that approach certain clinics with symptoms of that disease. The inferential objective is the rate at which a person appears in the system with that disease and further down the analysis the rate at which people get sick with this disease. A sample could be collected by nurses and medical techs filling statistical report sheets designed to detect symptoms of patients from hospitals and medical centers of the country selected as representative for the experiment.
#
# 4. The population of interest is the set of all transistors of a certain type. The inferential objective is the average length of life of the transistors of a certain type. To take a sample one would have to create a standard for transistors of certain type so that all manufacturers that build them put them under this test.
#
# 5. The population of interest is the U.S. citizens from "Generation X". The inferential objective is to find the proportion of "gen X" U.S. citizens interested in starting their own business. Work with banks to obtain the contact information of "Gen X" citizens and interview them.
#
# 6. The population of interest is the set of all healthy adults in the U.S. The inferential objective is to estimate the average temperature of the population using samples of healthy adults. Samples could be taken by using advertisements in health apps to determine which adults are healthy and then have them fill a form for data.
#
# 7. The population of interest are all families that consume water inside the city system. The inferential objective is the weekly rate at which water is consumed by families in the city. A sample could be taken by accessing public records and studying consumption for each service charge.

# %% [markdown]
# <style>
#   ol.spacing-alpha {
#     list-style-type: lower-alpha;
#     padding-left: 1.5em; /* indent */
#   }
#   ol.spacing-alpha li {
#     margin-bottom: 0.8em; /* vertical spacing */
#   }
#   ol.spacing-alpha li::marker {
#     font-weight: bold;
#   }
# </style>
#
# <style>
#   ol.spacing-num {
#     list-style-type: decimal;
#     padding-left: 1.5em; /* indent */
#   }
#   ol.spacing-num li {
#     margin-bottom: 0.8em; /* vertical spacing */
#   }
#   ol.spacing-num li::marker {
#     font-weight: bold;
#   }
# </style>
#
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.2**
# #### **Statement:**
#
# Are some cities more windy than others? Does Chicago deserve to be nicknamed "The Windy City"? Given below are the average wind speeds (in miles per hour) for 45 selected U.S. cities:
#
# <table class="borderless">
#   <tr>
#     <td>8.9</td>
#     <td>12.4</td>
#     <td>8.6</td>
#     <td>11.3</td>
#     <td>9.2</td>
#     <td>8.8</td>
#     <td>35.1</td>
#     <td>6.2</td>
#     <td>7.0</td>
#   </tr>
#   <tr>
#     <td>7.1</td>
#     <td>11.8</td>
#     <td>10.7</td>
#     <td>7.6</td>
#     <td>9.1</td>
#     <td>9.2</td>
#     <td>8.2</td>
#     <td>9.0</td>
#     <td>8.7</td>
#   </tr>
#   <tr>
#     <td>9.1</td>
#     <td>10.9</td>
#     <td>10.3</td>
#     <td>9.6</td>
#     <td>7.8</td>
#     <td>11.5</td>
#     <td>9.3</td>
#     <td>7.9</td>
#     <td>8.8</td>
#   </tr>
#   <tr>
#     <td>8.8</td>
#     <td>12.7</td>
#     <td>8.4</td>
#     <td>7.8</td>
#     <td>5.7</td>
#     <td>10.5</td>
#     <td>10.5</td>
#     <td>9.6</td>
#     <td>8.9</td>
#   </tr>
#   <tr>
#     <td>10.2</td>
#     <td>10.3</td>
#     <td>7.7</td>
#     <td>10.6</td>
#     <td>8.3</td>
#     <td>8.8</td>
#     <td>9.5</td>
#     <td>8.8</td>
#     <td>9.4</td>
#   </tr>
# </table>
#
#
# 1. Construct a relative frequency histogram for these data. (Choose the class boundaries without including the value 35.1 in the range of values.)
#
# 2. The value 35.1 was recorded at Mt. Washington, New Hampshire. Does the geography of that city explain the magnitude of its average wind speed?
#
# 3. The average wind speed for Chicago is 10.3 miles per hour. What percentage of the cities have average wind speeds in excess of Chicago's?
#
# 4. Do you think that Chicago is unusually windy?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
#
# 1. First create a list with the raw input data called `rawData`, then, the panda series is created and a new series is created without outlier 35.1. Finally, we plot the histograms with 10 bins and then 5 and 15 for comparison. The histograms have their y tick labels switched to relative frequency as asked by the instruction.
#
# 2. Yes, the city is in a mountainous terrain, which would make severe winds more common. A quick search online throws the result that wind conditions are common for this area.
# To find the amount of cities with excess wind speed from Chicago we first need to subset the Series to only include the cities with excess wind speed to Chicago.
#
# 3. For this sample, Chicago is more windy than 75% of the other cities in this data. A more general dataset could give more information on the fact that Chicago is unusually windy, but for this data set it is.
#
#
#
# **Code:**

# %%
rawData = [8.9, 12.4, 8.6, 11.3, 9.2, 8.8, 35.1, 6.2, 7.0,
            7.1, 11.8, 10.7, 7.6, 9.1, 9.2, 8.2, 9.0, 8.7,
            9.1, 10.9, 10.3, 9.6, 7.8, 11.5, 9.3, 7.9, 8.8,
            8.8, 12.7, 8.4, 7.8, 5.7, 10.5, 10.5, 9.6, 8.9,
            10.2, 10.3, 7.7, 10.6, 8.3, 8.8, 9.5, 8.8, 9.4]

ws_45 = pd.Series(rawData, name="wind_speed", dtype="float64[pyarrow]")

# ==========================> Answer to 1. <===============================

ws_top45_w_o_outlier = ws_45[ws_45 != 35.1]


# Plotting using pandas method
fig1, ax1 = plt.subplots()
number_ticks_ax1 = [i*2 for i in range(7)]
ws_top45_w_o_outlier.hist()
ax1.set_title("Histogram of wind speeds for 45 cities in U.S.")
ax1.set_xlabel("Wind Speed")
ax1.set_ylabel("Relative Frequency")
ax1.set_yticks(number_ticks_ax1)
ax1.set_yticklabels([round(i/ws_top45_w_o_outlier.count(), 2) for i in number_ticks_ax1])
plt.show()


# Plotting using axes and seaborn
fig2, ax2 = plt.subplots(2,1)
ax2[0].set_title("Histograms of wind speeds for 45 cities in U.S.")
ax2[1].set_xlabel("Wind Speed")
ax2[0].set_ylabel(r"Relative Frequency (\%)")
ax2[1].set_ylabel(r"Relative Frequency (\%)")
sns.histplot(x = ws_top45_w_o_outlier, stat = 'percent', bins = 5, ax = ax2[0])
sns.histplot(x = ws_top45_w_o_outlier, stat = 'percent', bins =15, ax = ax2[1])
plt.show()

# ==========================> Answer to 3. <===============================

cities_ws_bigger_than_chicago = ws_45[ws_45 > 10.3]
print("There are "
      + str(cities_ws_bigger_than_chicago.count()) 
      + " cities with average wind speed in excess of Chicago.")
print(str(round(100*cities_ws_bigger_than_chicago.count()/ws_45.count(),2))
      + "% of cities have excess wind speed on Chicago."
      )

# %% [markdown]
# #### A word about histograms.
# The book takes a focus on drawing histograms based on a special theory to observe data in the best way, but python allows the user the ability to look at histograms through a range of `bin` values that draw a different histogram using `matplotlib`.

# %%
# Reusing the data from last exercise without the outlier at 35.1
raw_data = [8.9, 12.4, 8.6, 11.3, 9.2, 8.8, 9.4, 6.2, 7.0,
            7.1, 11.8, 10.7, 7.6, 9.1, 9.2, 8.2, 9.0, 8.7,
            9.1, 10.9, 10.3, 9.6, 7.8, 11.5, 9.3, 7.9, 8.8,
            8.8, 12.7, 8.4, 7.8, 5.7, 10.5, 10.5, 9.6, 8.9,
            10.2, 10.3, 7.7, 10.6, 8.3, 8.8, 9.5, 8.8]

ws_45 = pd.Series(raw_data, name = "wind_speed", dtype="float64[pyarrow]")
bins = [i+1 for i in range(4,15, 2)]
nrows, ncols = 2, 3
figH, axH = plt.subplots(nrows=nrows,ncols=ncols)
figH.set_size_inches(10, 8)

for i,bin in enumerate(bins):
    print(i, "  ", bin)
    sns.histplot(x = ws_45, stat = 'percent', bins = bin, ax = axH[i//ncols][i%ncols])
    axH[i//ncols][i%ncols].set_title(f"Histogram with {bin} bins.", fontsize = 10)

axH[1,0].set_xlabel("Wind Speed")
axH[1,1].set_xlabel("Wind Speed")
axH[1,2].set_xlabel("Wind Speed")
axH[0,0].set_ylabel(r"Relative Frequency (\%)")
axH[1,0].set_ylabel(r"Relative Frequency (\%)")


figH.suptitle("Bins iteration to visualize python drawing power", fontsize=16)



## REPORTE W0105914504

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.3**
# #### **Statement:**
#
# Of great importance to residents of central Florida is the amount of radioactive material present in the soil of reclaimed phosphate mining areas. Measurements of the amount of <sup>238</sup>U in 25 soil samples were as follows (measurements in picocuries per gram):
#
# <table class="borderless">
#   <tr>
#     <td>0.74</td>
#     <td>6.47</td>
#     <td>1.90</td>
#     <td>2.69</td>
#     <td>0.75</td>
#   </tr>
#   <tr>
#     <td>0.32</td>
#     <td>9.99</td>
#     <td>1.77</td>
#     <td>2.41</td>
#     <td>1.96</td>
#   </tr>
#   <tr>
#     <td>1.66</td>
#     <td>0.70</td>
#     <td>2.42</td>
#     <td>0.54</td>
#     <td>3.36</td>
#   </tr>
#   <tr>
#     <td>3.59</td>
#     <td>0.37</td>
#     <td>1.09</td>
#     <td>8.32</td>
#     <td>4.06</td>
#   </tr>
#   <tr>
#     <td>4.55</td>
#     <td>0.76</td>
#     <td>2.03</td>
#     <td>5.70</td>
#     <td>12.48</td>
#   </tr>
# </table>
#
# Construct a relative frequency histogram for these data.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
# The construction of a relative frequency histogram is like in the previous exercise.
#
# **Code:**

# %%
raw_data = [0.74, 6.47, 1.90, 2.69, .75,
            0.32, 9.99, 1.77, 2.41, 1.96,
            1.66, 0.70, 2.42, 0.54, 3.36,
            3.59, 0.37, 1.09, 8.32, 4.06,
            4.55, 0.76, 2.03, 5.70, 12.48
            ]

radioactive_samples = pd.Series(raw_data, name="picocuries_per_gram", dtype="float64[pyarrow]")

fig3, ax3 = plt.subplots()
sns.histplot(x = radioactive_samples, stat = 'percent', bins = 7, ax = ax3)
ax3.set_title("Frequencies of the radioactive measurements of U present in 25 soil samples.")
ax3.set_xlabel("Picocuries per gram")
ax3.set_ylabel(r"Relative Frequency (\%)")
plt.show()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.4**
# #### **Statement:**
#
# The top 40 stocks on the over-the-counter (OTC) market, ranked by percentage of outstanding shares traded on one dat last year are as follows:
#
# <table class="borderless">
#   <tr>
#     <td>11.88</td>
#     <td>6.27</td>
#     <td>5.49</td>
#     <td>4.81</td>
#     <td>4.40</td>
#     <td>3.78</td>
#     <td>3.44</td>
#     <td>3.11</td>
#     <td>2.88</td>
#     <td>2.68</td>
#   </tr>
#   <tr>
#     <td>7.99</td>
#     <td>6.07</td>
#     <td>5.26</td>
#     <td>4.79</td>
#     <td>4.05</td>
#     <td>3.69</td>
#     <td>3.36</td>
#     <td>3.03</td>
#     <td>2.74</td>
#     <td>2.63</td>
#   </tr>
#   <tr>
#     <td>7.15</td>
#     <td>5.98</td>
#     <td>5.07</td>
#     <td>4.55</td>
#     <td>3.94</td>
#     <td>3.62</td>
#     <td>3.26</td>
#     <td>2.99</td>
#     <td>2.74</td>
#     <td>2.62</td>
#   </tr>
#   <tr>
#     <td>7.13</td>
#     <td>5.91</td>
#     <td>4.94</td>
#     <td>4.43</td>
#     <td>3.93</td>
#     <td>3.48</td>
#     <td>3.20</td>
#     <td>2.89</td>
#     <td>2.69</td>
#     <td>2.61</td>
#   </tr>
# </table>
#
#
#   Construct a relative frequency histogram to describe these data.
#   What proportion of these top 40 stocks traded more than 4% of the outstanding shares?
#   If one of the stocks is selected at random from the 40 for which the preceding data were taken, what is the probability that it will have traded fewer than 5% of its outstanding shares.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
# 1. We use the usual histogram method.
# 2. We subset the Series to values bigger than 4 and divide the size of this subset by the size of the original Series.
# 3. WE subset the series to values smaller than 5 and divide the size of this subset by the size of the original series.
#
#
# **Code:**

# %%
raw_data = [11.88, 6.27, 5.49, 4.81, 4.40, 3.78, 3.44, 3.11, 2.88, 2.68,
            7.99, 6.07, 5.26, 4.79, 4.05, 3.69, 3.36, 3.03, 2.74, 2.63,
            7.15, 5.98, 5.07, 4.55, 3.94, 3.62, 3.26, 2.99, 2.74, 2.62,
            7.13, 5.91, 4.94, 4.43, 3.93, 3.48, 3.20, 2.89, 2.69, 2.61
            ]

outstanding_shares_stock_OTC = pd.Series(raw_data, name="outstanding_shares_percent", dtype="float64[pyarrow]")

# ==========================> Answer to 1. <===============================

fig4, ax4 = plt.subplots()
sns.histplot(x = outstanding_shares_stock_OTC, stat = 'percent', ax = ax4)
ax4.set_title("Top 40 stocks OTC")
ax4.set_xlabel("Percentage of outstanding shares")
ax4.set_ylabel(r"Relative Frequency (\%)")
plt.show()

# ==========================> Answer to 2. <===============================

print("More than " + str(round(100*outstanding_shares_stock_OTC[outstanding_shares_stock_OTC > 4].count()/outstanding_shares_stock_OTC.count(),2))
        + f"% of outstanding shares are traded with more than 4% of the outstanding shares."
        )
print()

# ==========================> Answer to 3. <===============================

print(f"The probability that when selecting a stock at random that is fewer than 5% is "
      + str(round(outstanding_shares_stock_OTC[outstanding_shares_stock_OTC < 5].count()/outstanding_shares_stock_OTC.count(), 2))
      )

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.5**
# #### **Statement:**
#
# Given here is the relative frequency histogram associated with grade point averages (GPAs) of a sample of 30 students:
#
# <center><img src="im1.png" alt="im1" width="400px"/></center>
#
#
# 1. Which of the GPA categories identified on the horizontal axis are associated with the largest proportion of students?
# 2. What proportion of students had GPAs in each of the categories that you identified?
# 3. What proportion of the students had GPAs less than 2.65?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
#
# 1. Both the categories where  $2.45 < \mathrm{GPA} < 2.65$  and  $2.65 < \mathrm{GPA} < 2.85$.
# 2. The proportion of students is is 7/30 for each of the categories.
# 3. The proportion of students with $\mathrm{GPA} < 2.65$ is the value that the bars of the histogram reach for every bar lower than the 2.65 mark:
#
# \begin{align*}
# \mathrm{Proportion}(\mathrm{GPA} < 2.65) = \frac{7}{30} + 3\frac{3}{30}\approx0.5333
# \end{align*}

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.6**
# #### **Statement:**
#
# The relative frequency histogram given next was constructed from data obtained from a random sample of 25 families. Each was asked the number of quarts of milk that had been purchased the previous week.
#
# <center><img src="im2.png" alt="im2" width="400px"/></center>
#
# 1. Use this relative frequency histogram to determine the number of quarts of milk purchased by the largest proportion of the 25 families. The category associated with the largest relative frequency is called the *modal category*.
#
# 2. What proportion of the 25 families purchased more than 2 quarts of milk?
#
# 3. What proportion purchased more than 0 but fewer than 5 quarts?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
# 1. The largest proportion of quarts of milk purchased is the category of 2 quarts purchased last week.
#
# 2. The proportion that bought more than 2 quarts of milk is:
# \begin{align*}
# \mathrm{Proportion}(\mathrm{Quarts} > 4) =& \mathrm{Proportion}(\mathrm{Quarts} = 3) + \mathrm{Proportion}(\mathrm{Quarts} = 4) + \mathrm{Proportion}(\mathrm{Quarts} = 5) \\
# =& 0.2 + 0.12 + 0.04 = 0.36
# \end{align*}
#   This is obtained by looking at the histogram and obtaining the values of intersection.
#
#   <center><img src="im3.png" alt="im3" width="400px"/></center>
#
# 3. The categories that have more than 0 but fewer than 5 quarts are $C = \{1,2,3,4 \} $. Interpreting the histogram we have:
# \begin{align*}
# \mathrm{Proportion}(0<\mathrm{Quarts}<5) = 0.2 + 0.36 + 0.2 + 0.12 = 0.88
# \end{align*}

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# ### **Exercise 1.7**
# #### **Statement:**
#
# The self-reported heights of 105 students in a biostatistics class were used to construct the histogram given below.
#
# <center><img src="im4.png" alt="im4" width="400px"/></center>
#
# 1. Describe the shape of the histogram.
#
# 2. Does this histogram have an unusual feature?
#
# 3. Can you think of an explanation for the two peaks in the histogram? Is there some consideration other than height that results in the two separate peaks? What is it?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
# 1. This histogram appears to have two main features to note. First, there appears to be a peak in the histogram data manifesting around 64. Secondly, a tendency towards the value 69.
#
# 2. Yes, the peaks in the histogram show the influence of the population means in a sample. Also the bin for 68 has a drop in frequency because of the distance between the reported means.
#
# 3. Yes, the first peak coincides with a reported value called "the average height in the US for women" available online of about 64 inches. The second peak centered around a reported value called "the average height in the US for male" available online, which is about 69 inches.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.8**
# #### **Statement:**
#
# An article in *Archaeometry* presented an analysis of 26 samples of Romano-British pottery, found at four different kiln sites in the United Kingdom. The percentage of aluminum oxide in each of the 26 samples is given below:
#
#
# <center><table class="linetop-borderless">
#   <thead>
#     <tr>
#       <th>Llanederyn</th>
#       <th>Caldicot</th>
#       <th>Island Thorns</th>
#       <th>Ashley Rails</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td>14.4 &emsp; 11.6</td><center><td>11.8</td></center><td>18.3</td><td>17.7</td></tr>
#     <tr><td>13.8 &emsp; 11.1</td><td>11.6</td><td>15.8</td><td>18.3</td></tr>
#     <tr><td>14.6 &emsp; 13.4</td><td></td><td>18.0</td><td>16.7</td></tr>
#     <tr><td>11.5 &emsp; 12.4</td><td></td><td>18.0</td><td>14.8</td></tr>
#     <tr><td>13.8 &emsp; 13.1</td><td></td><td>20.8</td><td>19.1</td></tr>
#     <tr><td>10.9 &emsp; 12.7</td><td></td><td></td><td></td></tr>
#     <tr><td>10.1 &emsp; 12.5</td><td></td><td></td><td></td></tr>
#   </tbody>
# </table></center>
#
# *Source:* A. Tubb, A. J. Parker, and G. Nickless, “The Analysis of Romano–British Pottery by Atomic
# Absorption Spectrophotometry,” *Archaeometry* 22 (1980): 153.
#
# 1. Construct a relative frequency histogram to describe the aluminum oxide content of all 26 pottery samples.
#
# 2. What unusual feature do you see in this histogram? Looking at the data, can you think of an explanation for this unusual feature?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 8)
#
# #### **Solution**
# **Theory Section:**
#
# 1. To construct the relative frequency histogram of all samples with the method used previously.
#
# 2. Looking at the histogram it appears that the cities of Llanederyn and Caldicot have similar raw materials, besides, Island Thorns and Ashley Rails have similar raw materials.
#
# **Code:**

# %%
raw_data = [14.4, 11.6, 11.8, 18.3, 17.7,
            13.8, 11.1, 11.6, 15.8, 18.3,
            14.6, 13.4, 18.0, 16.7,
            11.5, 12.4, 18.0, 14.8,
            13.8, 13.1, 20.8, 19.1,
            10.9, 12.7,
            10.1, 12.5,
            ]

aluminum_oxide_samples = pd.Series(raw_data, name="percentage", dtype="float64[pyarrow]")

fig5, ax5 = plt.subplots()
sns.histplot(x = aluminum_oxide_samples, stat = 'percent', bins = 10, ax = ax5)
ax5.set_xlabel("Percentage of aluminum in sample.")
ax5.set_ylabel(r"Relative Frequency (\%)")
ax5.set_title("Relative Frequencies of Percentages of Aluminum Oxide in Samples")

plt.show()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.9**
# #### **Statement:**
#
# Resting breathing rates for college-age students are approximately normally distributed with mean 12 and standard deviation 2.3 breaths per minute. What fraction of all college-age students have breathing rates in the following intervals?
#
# 1. 9.7 to 14.3 breaths per minute.
#
# 2. 7.4 to 16.6 breaths per minute.
#
# 3. 9.7 to 16.6 breaths per minute.
#
# 4. Less than 5.1 or more than 18.9 breaths per minute.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. X)
#
# #### **Solution**
# **Theory Section:**
#
# 1. We find that $9.7 + 2.3 = 12$ and $14.3 - 2.3 = 12$, this creates an interval with endpoints $ \mu \pm \sigma$ which contains approximately 68% of the measurements.
#
# 2. We find that $7.4 + 2(2.3) = 12$ and $16.6 - 2(2.3) = 12$, this creates an interval with endpoints $ \mu \pm 2\sigma $ which contains approximately 95% of the measurements.
#
# 3. Having $9.7 + 2.3 = 12$ and $16.6 - 2(2.3) = 12$, this creates the interval with endpoints $\left[\mu-\sigma, \mu + 2\sigma \right]$, this interval contains is the union of intervals $\left[\mu-\sigma,\mu\right]$ and $\left[\mu, \mu + 2\sigma\right]$. The first fractionate interval ($\left[\mu-\sigma,\mu\right]$) contains half of the interval with endpoints $\mu \pm \sigma$. The second interval ($\left[\mu, \mu + 2\sigma\right]$) contains half of the interval with endpoints $\mu \pm 2\sigma$. The addition of the proportion follows:
#
# \begin{align*}
# \mathrm{Proportion} ([ \mu -\sigma, \mu + 2 \sigma ] ) = \frac{\mathrm{Proportion} ( \left[\mu - \sigma,\mu + \sigma \right])}{2} + \frac{ \mathrm{Proportion} ( \left[\mu - 2 \sigma,\mu + 2 \sigma \right] ) }{2} = \frac{68\%}{2} + \frac{95\%}{2} = 34\% + 47.5 \% = 81.5\%
# \end{align*}
#
#
# &emsp;&emsp;&ensp;This is an approximation, the exact value might be different. The region under the  normal distribution and its proportion of the total measurements is shown in the code section.
#
#
# 4. For this interval, we have the union of intervals $\left(- \infty, \mu - 3\sigma \right] \bigcup \left[\mu + 3 \sigma, \infty \right)$, which is outside the range for most measurements and very small. An exact value is calculated in the code below.
#
# **Code:**

# %%
# Definition
mu = 12         
sigma = 2.3      
dist = norm(loc=mu, scale=sigma)

# Values of the probability function
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 500)
y = dist.pdf(x)    

# ==========================> Answer to 3. <===============================

# Figure and ax definition
fig6, ax6 = plt.subplots(figsize=(8, 3))
ax6.plot(x, y, color="black", lw=2)

# Vertical lines
for k in [-3, -2, -1, 0, 1, 2, 3]:
    ax6.axvline(mu + k*sigma, color="black", lw=1)

# Fill area under graph
mask = (x >= mu - sigma) & (x <= mu + 2*sigma)
ax6.fill_between(x[mask], y[mask], alpha=0.3)

# Visuals
ax6.set_ylim(0, y.max()*1.1)
ax6.set_xticks([mu + 2.3*sigma for sigma in np.linspace(-3, 3,num = 7)])
ax6.set_xticklabels([r"$\mu - 3\sigma$", r"$\mu - 2\sigma$", r"$\mu - \sigma$", r"$\mu$", r"$\mu + \sigma$", r"$\mu + 2\sigma$", r"$\mu + 3\sigma$"])
ax6.set_yticks([])

print("For the interval in 3, the proportion is:")
plt.show()

prop = norm.cdf(mu + 2*sigma, mu, sigma) - norm.cdf(mu - sigma, mu, sigma)
print(f"The proportion of the measurements in 3 is {prop*100:.2f}%")
print()

# ==========================> Answer to 4. <===============================

prop2 = 2*norm.cdf(mu-3*sigma, mu, sigma)
print(f"The proportion of the measurements in 4 is {prop2*100:.2f}%")

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.10**
# #### **Statement:**
#
# It has been projected that the average and standard deviation of the amount of time spent online using the internet are, respectively, 14 and 17 hours per person per year (many do not use the Internet at all!).
#
# 1. What value is exactly 1 standard deviation below the mean?
#
# 2. If the amount of time spent online using the Internet is approximately normally distributed, what proportion of the users spend an amount of time online that is less than the vale you found in part (a)?
#
# 3. Is the amount of time spent online using the Internet approximately normally distributed? Why?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. X)
#
# #### **Solution**
# **Theory Section:**
#
# 1. 1 standard deviation below the mean is $14 - 17 = -3$.
#
# 2. If the distribution is normal then the proportion os users is $\frac{100\% - 68\%}{2} = 16\%$
#
# 3. No, it shouldn't be normally distributed since the value of -3 hours per week makes no sense. The proportion of measurements from negative values is included in the code.  The value is $20\%$ which would mean that 1 in 5 people spend negative time online which makes no physical sense.
#
# **Code:**

# %%
prop = norm.cdf(0, 14, 17)
print(f"The proportion of measurements from negative values would be {prop*100:.2f}% if the distribution was normal.")

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.11**
# #### **Statement:**
#
# The following results on summations will help us in calculating the sample variance $s^{2}$. For any constant $c$.
#
# 1. $\sum_{i=1}^{n}c=nc$.
#
# 2. $\sum_{i=1}^{n}cy_{i} = c \sum_{i=1}^{n}y_{i}$.
#
# 3. $\sum_{i=1}^{n}(x_{i}+y_{i})=\sum_{i=1}^{n}y_{i}^{2} + \sum_{i=1}^{n}y_{i}$.
#
# Use (1), (2) and (3) to show that
#
# \begin{align*}
# s^{2} = \frac{1}{n-1} \sum_{i=1}^{n}(y_{i} - \bar{y})^{2} = \frac{1}{n-1}\left[ \sum_{i=1}^{n}y_{i}^{2}-\frac{1}{n} \left( \sum_{i=1}^{n} y_{i} \right)^{2} \right]
# \end{align*}
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. X)
#
# #### **Solution**
# **Theory Section:**
#
# To show that the equation holds, start from the left side
#
# \begin{align*}
# s^{2} = \frac{1}{n-1} \sum_{i=1}^{n}(y_{i} - \bar{y})^{2} =& \frac{1}{n-1} \sum_{i=1}^{n} \left( y_{i}^{2} - 2y_{i}\bar{y}+\bar{y}^{2} \right) \\
# =& \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \sum_{i=1}^{n} \left( - 2y_{i}\bar{y}+\bar{y}^{2} \right) \right]
# \end{align*}
#
# Using 3, then
#
# \begin{align*}
# \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \sum_{i=1}^{n} \left( - 2y_{i}\bar{y}+\bar{y}^{2} \right) \right] =& \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \bar{y}\sum_{i=1}^{n} \left( - 2y_{i}+\bar{y} \right) \right]
# \end{align*}
#
# By using 2, then using 3 again
#
# \begin{align*}
# \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \bar{y}\sum_{i=1}^{n} \left( - 2y_{i}+\bar{y} \right) \right] =& \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \bar{y} \left( - 2\sum_{i=1}^{n}y_{i}+ \sum_{i=1}^{n} \bar{y} \right) \right] \\
# =& \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \bar{y} \left( - 2\sum_{i=1}^{n}y_{i}+ n \bar{y} \right) \right]
# \end{align*}
#
# Because $\sum_{i=1}^{n}\bar{y} = n\bar{y}$, furthermore
#
# \begin{align*}
# \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \bar{y} \left( - 2\sum_{i=1}^{n}y_{i}+ n \bar{y} \right) \right] =& \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} +  \frac{1}{n} \sum_{i=1}^{n} y_{i} \left( - 2\sum_{i=1}^{n}y_{i}+ \sum_{i=1}^{n} y_{i} \right) \right] \\
# =& \frac{1}{n-1} \left[ \sum_{i=1}^{n} y_{i}^{2} -  \frac{1}{n} \left( \sum_{i=1}^{n} y_{i} \right)^{2} \right]
# \end{align*}
#
# Which reaches the right side of the equation to prove.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.12**
# #### **Statement:**
#
# Use the result of Exercise 1.11 to calculate $s$ for the $n=6$ sample measurements 1, 4, 2, 1, 3, and 3.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. X)
#
# #### **Solution**
# **Theory Section:**
#
# Using python to compare different implementations that can be done for the variance calculation, first the classic definition, then the result of exercise 1.11 and finally using the numpy `np.var()` function with up to 4 decimal digits.
#
# **Code:**

# %%
# First define variance using the classic implementation

def varianceClassic(vector):
    var = 0
    mean = np.mean(vector)
    for y in vector:
        var += (y - mean) **2
    return var/(np.size(vector)-1)


# Secondly define variance by the result of exercise 1.11

def variance1_11(vector):
    sum1 = np.sum(vector*vector)
    sum2 = np.sum(vector)
    return (sum1 - (pow(sum2, 2))/(np.size(vector)))/(np.size(vector)-1)

# Finally we compute the data and the variances

data = np.array([1, 4, 2, 1, 3, 3])

print(f"The classic variance for this data is {varianceClassic(data):.4f}.")
print()
print(f"The variance using the result of exercise 1.11 is {variance1_11(data):.4f}.")
print()
print(f"The variance using numpy is {np.var(data, ddof = 1):.4f}.") # Here we use the ddof parameter for the variance to divide by n - 1 and not by n which is default.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.13**
# #### **Statement:**
#
# Refer to Exercise 1.2.
#
# 1. Calculate $\bar{y}$ and $s$ for the data given.
#
# 2. Calculate the interval $\bar{y} \pm ks$ for $k=1,2$ and $3$. Count the number of measurements that fall within each interval and compare this result with the number that you would expect according to the empirical rule.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# 1. For this exercise the values are calculated quickly by the methods of the pandas series.
#
# 2. This answer has for each of the intervals $\bar{y} \pm ks$ for $k=1,2$ and $3$, the same percentage of measurements contained in each of the intervals, this is due to the outlier `35.1` that exists in the dataset, increasing the dispersion measurement. An evaluation of the same measurements without the outlier is included.
#
# **Code:**

# %%
raw_data = [8.9, 12.4, 8.6, 11.3, 9.2, 8.8, 35.1, 6.2, 7.0,
            7.1, 11.8, 10.7, 7.6, 9.1, 9.2, 8.2, 9.0, 8.7,
            9.1, 10.9, 10.3, 9.6, 7.8, 11.5, 9.3, 7.9, 8.8,
            8.8, 12.7, 8.4, 7.8, 5.7, 10.5, 10.5, 9.6, 8.9,
            10.2, 10.3, 7.7, 10.6, 8.3, 8.8, 9.5, 8.8, 9.4]

# ==========================> Answer to 1. <===============================

ws = pd.Series(raw_data, name = "wind_speed", dtype = "float64[pyarrow]")
mean = ws.mean()
std = ws.std()

print(f"For this data, the mean is {mean:.2f}, the standard deviation is {std:.2f}.")
print()

# ==========================> Answer to 2. <===============================

print("For the interval [m - 3s, m + 3s], where m is the sample mean.")
percentage1 = 100*(ws[(ws >= mean - 3*std) & (ws <= mean + 3*std)].size/ws.size)
print(f"In this interval there are {percentage1:.2f}% of measurements vs the expected 99.7%")
print()

percentage2 = 100*(ws[ (ws >=  mean - 2*std) & (ws <= mean + 2*std)].size/ws.size)
print("For the interval [m - 2s, m + 2s].")
print(f"In this interval there are {percentage2:.2f}% of measurements vs the expected 95%")
print()

percentage3 = 100*(ws[ (ws >=  mean - std) & (ws <= mean + std)].size/ws.size)
print("For the interval [m - s, m + s].")
print(f"In this interval there are {percentage3:.2f}% of measurements vs the expected 68%")
print()

# Checking the percentages without the outlier.
ws_without_outlier = ws.drop(6).reset_index(drop=True)
mean_wo_outlier = ws_without_outlier.mean()
std_wo_outlier = ws_without_outlier.std()
percentages = [100*(ws_without_outlier[ (ws_without_outlier >=  mean_wo_outlier - k*std_wo_outlier) & (ws_without_outlier <= mean_wo_outlier + k*std)].size/ws_without_outlier.size) for k in [1,2,3]]
print("Without the outliers:")
print(f"In the interval [m - 3s, m + 3s] there are {percentages[2]:.2f}% of measurements vs the expected 99.7%")
print(f"In th3 interval [m - 2s, m + 2s] there are {percentages[1]:.2f}% of measurements vs the expected 95%")
print(f"In the interval [m - s, m + s] there are {percentages[0]:.2f}% of measurements vs the expected 68%")
print()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.14**
# #### **Statement:**
#
# Refer to Exercise 1.3 and repeat parts (1) (2) of Exercise 1.13
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# Solving this exercise repeats the method used in the previous, the implementations is straightforward.
#
# 1. Using the methods of a Pandas series we can find the solutions to this part.
#
# 2. There are no outliers in this data, when calculating for the intervals the percentage of measurements resembles the theory.
#
# **Code:**

# %%
raw_data = [0.74, 6.47, 1.90, 2.69, .75,
            0.32, 9.99, 1.77, 2.41, 1.96,
            1.66, 0.70, 2.42, 0.54, 3.36,
            3.59, 0.37, 1.09, 8.32, 4.06,
            4.55, 0.76, 2.03, 5.70, 12.48]

# ==========================> Answer to 1. <===============================

soil_samples = pd.Series(raw_data, name = "pico_curies_per_gram", dtype = "float64[pyarrow]")
soil_mean = soil_samples.mean()
soil_std = soil_samples.std()

print(f"For this data, the mean is {soil_mean:.2f}, the standard deviation is {soil_std:.2f}.")
print()

# ==========================> Answer to 2. <===============================

print("For the interval [m - 3s, m + 3s], where m is the sample mean.")
percentage1 = 100*(soil_samples[(soil_samples >= soil_mean - 3*soil_std) & (soil_samples <= soil_mean + 3*soil_std)].size/soil_samples.size)
print(f"In this interval there are {percentage1:.2f}% of measurements vs the expected 99.7%")
print()

print("For the interval [m - 2s, m + 2s], where m is the sample mean.")
percentage2 = 100*(soil_samples[(soil_samples >= soil_mean - 2*soil_std) & (soil_samples <= soil_mean + 2*soil_std)].size/soil_samples.size)
print(f"In this interval there are {percentage2:.2f}% of measurements vs the expected 95%")
print()

print("For the interval [m - s, m + s], where m is the sample mean.")
percentage3 = 100*(soil_samples[(soil_samples >= soil_mean - soil_std) & (soil_samples <= soil_mean + soil_std)].size/soil_samples.size)
print(f"In this interval there are {percentage3:.2f}% of measurements vs the expected 68%")
print()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.15**
# #### **Statement:**
#
# Refer to Exercise 1.4 and repeat parts (a) and (b) of Exercise 1.13.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# The answer to this exercise follows the same implementation as the previous.
#
# 1. The calculations are made with the methods of the Pandas Series object.
#
# 2. The percentage of measurements in each range is calculated like in the previous two exercises. Note that this sample is distributed closer to the mean. There is an outlier in this data, but the next exercise deals with it.
#
# **Code:**

# %%
raw_data = [11.88, 6.27, 5.49, 4.81, 4.40, 3.78, 3.44, 3.11, 2.88, 2.68,
            7.99, 6.07, 5.26, 4.79, 4.05, 3.69, 3.36, 3.03, 2.74, 2.63,
            7.15, 5.98, 5.07, 4.55, 3.94, 3.62, 3.26, 2.99, 2.74, 2.62,
            7.13, 5.91, 4.94, 4.43, 3.93, 3.48, 3.20, 2.89, 2.69, 2.61]

# ==========================> Answer to 1. <===============================

outstanding_shares = pd.Series(raw_data, name = "percentage", dtype="float64[pyarrow]")
shares_mean = outstanding_shares.mean()
shares_std = outstanding_shares.std()

print(f"For this data, the mean is {shares_mean:.2f}, the standard deviation is {shares_std:.2f}.")
print()

# ==========================> Answer to 2. <===============================

print("For the interval [m - 3s, m + 3s], where m is the sample mean.")
percentage1 = 100*(outstanding_shares[(outstanding_shares >= shares_mean - 3*shares_std) & (outstanding_shares <= shares_mean + 3*shares_std)].size/outstanding_shares.size)
print(f"In this interval there are {percentage1:.2f}% of measurements vs the expected 99.7%")
print()

print("For the interval [m - 2s, m + 2s], where m is the sample mean.")
percentage2 = 100*(outstanding_shares[(outstanding_shares >= shares_mean - 2*shares_std) & (outstanding_shares <= shares_mean + 2*shares_std)].size/outstanding_shares.size)
print(f"In this interval there are {percentage2:.2f}% of measurements vs the expected 95%")
print()

print("For the interval [m - s, m + s], where m is the sample mean.")
percentage3 = 100*(outstanding_shares[(outstanding_shares >= shares_mean - shares_std) & (outstanding_shares <= shares_mean + shares_std)].size/outstanding_shares.size)
print(f"In this interval there are {percentage3:.2f}% of measurements vs the expected 68%")
print()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.16**
# #### **Statement:**
#
# In Exercise 1.4, there is one extremely large value (11.88). Eliminate this value and calculate $\bar{y}$ and $s$ for the remaining 39 observations. Also, calculate the intervals $\bar{y} \pm ks$ for $k = 1, 2,$ and $3$; count the number of measurements in each; then compare these results with those predicted by the empirical rule. Compare the answers here to those found in Exercise 1.15. Note the effect of a single large observation on $\bar{y}$ and $s$.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# Here we find the solution by copy-pasting (not following the best programming practices, since I believe sometimes handwork can be rewarding. Function implementations will happen in further exercises) the solution of the previous exercise and then eliminating the outlier number $11.88$ and then repeating the same process but with renamed variables.
#
# **Code:**

# %%
raw_data = [11.88, 6.27, 5.49, 4.81, 4.40, 3.78, 3.44, 3.11, 2.88, 2.68,
            7.99, 6.07, 5.26, 4.79, 4.05, 3.69, 3.36, 3.03, 2.74, 2.63,
            7.15, 5.98, 5.07, 4.55, 3.94, 3.62, 3.26, 2.99, 2.74, 2.62,
            7.13, 5.91, 4.94, 4.43, 3.93, 3.48, 3.20, 2.89, 2.69, 2.61]

raw_data_wo_outlier = [6.27, 5.49, 4.81, 4.40, 3.78, 3.44, 3.11, 2.88, 2.68,
            7.99, 6.07, 5.26, 4.79, 4.05, 3.69, 3.36, 3.03, 2.74, 2.63,
            7.15, 5.98, 5.07, 4.55, 3.94, 3.62, 3.26, 2.99, 2.74, 2.62,
            7.13, 5.91, 4.94, 4.43, 3.93, 3.48, 3.20, 2.89, 2.69, 2.61]

# ==========================> Answer to 1. <===============================

outstanding_shares = pd.Series(raw_data, name = "percentage", dtype="float64[pyarrow]")
shares_mean = outstanding_shares.mean()
shares_std = outstanding_shares.std()

outstanding_shares_wo_outlier = pd.Series(raw_data_wo_outlier, name = "percentage", dtype="float64[pyarrow]")
shares_mean_wo_outlier = outstanding_shares_wo_outlier.mean()
shares_std_wo_outlier = outstanding_shares_wo_outlier.std()

print(f"The mean with 11.88 is {shares_mean:.2f}, the standard deviation is {shares_std:.2f}.")
print(f"The mean without 11.88 is {shares_mean_wo_outlier:.2f}, the standard deviation is {shares_std_wo_outlier:.2f}.")
print()

# ==========================> Answer to 2. <===============================

print("For the interval [m - 3s, m + 3s] with 11.88, where m is the sample mean.")
percentage1 = 100*(outstanding_shares[(outstanding_shares >= shares_mean - 3*shares_std) & (outstanding_shares <= shares_mean + 3*shares_std)].size/outstanding_shares.size)
print(f"In this interval there are {percentage1:.2f}% of measurements vs the expected 99.7%")
print()

print("For the interval [m - 2s, m + 2s] with 11.88, where m is the sample mean.")
percentage2 = 100*(outstanding_shares[(outstanding_shares >= shares_mean - 2*shares_std) & (outstanding_shares <= shares_mean + 2*shares_std)].size/outstanding_shares.size)
print(f"In this interval there are {percentage2:.2f}% of measurements vs the expected 95%")
print()

print("For the interval [m - s, m + s] with 11.88, where m is the sample mean.")
percentage3 = 100*(outstanding_shares[(outstanding_shares >= shares_mean - shares_std) & (outstanding_shares <= shares_mean + shares_std)].size/outstanding_shares.size)
print(f"In this interval there are {percentage3:.2f}% of measurements vs the expected 68%")
print()

# Without outlier calculations

print("For the interval [m - 3s, m + 3s] without 11.88, where m is the sample mean.")
percentage1_wo_outlier = 100*(outstanding_shares_wo_outlier[(outstanding_shares_wo_outlier >= shares_mean_wo_outlier - 3*shares_std_wo_outlier) & (outstanding_shares_wo_outlier <= shares_mean_wo_outlier + 3*shares_std_wo_outlier)].size/outstanding_shares_wo_outlier.size)
print(f"In this interval there are {percentage1_wo_outlier:.2f}% of measurements vs the expected 99.7%")
print()

print("For the interval [m - 2s, m + 2s] without 11.88, where m is the sample mean.")
percentage2_wo_outlier = 100*(outstanding_shares_wo_outlier[(outstanding_shares_wo_outlier >= shares_mean_wo_outlier - 2*shares_std_wo_outlier) & (outstanding_shares_wo_outlier <= shares_mean_wo_outlier + 2*shares_std_wo_outlier)].size/outstanding_shares_wo_outlier.size)
print(f"In this interval there are {percentage2_wo_outlier:.2f}% of measurements vs the expected 95%")
print()

print("For the interval [m - s, m + s] without 11.88, where m is the sample mean.")
percentage3_wo_outlier = 100*(outstanding_shares_wo_outlier[(outstanding_shares_wo_outlier >= shares_mean_wo_outlier - shares_std_wo_outlier) & (outstanding_shares_wo_outlier <= shares_mean_wo_outlier + shares_std_wo_outlier)].size/outstanding_shares_wo_outlier.size)
print(f"In this interval there are {percentage3_wo_outlier:.2f}% of measurements vs the expected 68%")
print()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.17**
# #### **Statement:**
#
# The *range* of a set of measurements is the difference between the largest and the smallest values. The empirical rule suggests that the standard deviation of a set of measurements may be roughly approximated by one-fourth of the range (that is, $\mathrm{range}/4$). Calculate this approximation to $s$ for the data sets in Exercises 1.2, 1.3, and 1.4. Compare the result in each case to the actual, calculated value of $s$.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# The solution to this exercise comes by calculates the defined approximation for the standard deviation of a sample by dividing its range by 4 ($s \approx \frac{\mathrm{range}}{4}$) and using the function `stdev()` from the `statistics` built int package.
#
# **Code:**

# %%
datasets = {
                "Ex 1.2": [8.9, 12.4, 8.6, 11.3, 9.2, 8.8, 35.1, 6.2, 7.0,
                            7.1, 11.8, 10.7, 7.6, 9.1, 9.2, 8.2, 9.0, 8.7,
                            9.1, 10.9, 10.3, 9.6, 7.8, 11.5, 9.3, 7.9, 8.8,
                            8.8, 12.7, 8.4, 7.8, 5.7, 10.5, 10.5, 9.6, 8.9,
                            10.2, 10.3, 7.7, 10.6, 8.3, 8.8, 9.5, 8.8, 9.4],
                
                "Ex 1.3": [0.74, 6.47, 1.90, 2.69, .75,
                            0.32, 9.99, 1.77, 2.41, 1.96,
                            1.66, 0.70, 2.42, 0.54, 3.36,
                            3.59, 0.37, 1.09, 8.32, 4.06,
                            4.55, 0.76, 2.03, 5.70, 12.48],

                "Ex 1.4": [11.88, 6.27, 5.49, 4.81, 4.40, 3.78, 3.44, 3.11, 2.88, 2.68,
                            7.99, 6.07, 5.26, 4.79, 4.05, 3.69, 3.36, 3.03, 2.74, 2.63,
                            7.15, 5.98, 5.07, 4.55, 3.94, 3.62, 3.26, 2.99, 2.74, 2.62,
                            7.13, 5.91, 4.94, 4.43, 3.93, 3.48, 3.20, 2.89, 2.69, 2.61]
            }

# Calculo de los rangos

def range_and_std(values):
    """
    Returns:
          - R/4 . The approximation of the standard deviation, where R is the range of values.
          - s . The value of the standard deviation of values.
    """
    data_range = max(values) - min(values)
    return data_range/4, stdev(values)

# Respuesta del ejercicio

for label, data in datasets.items():
    approx, exact = range_and_std(data)
    print(f"{label} R/4 = {approx:.2f}   s = {exact:.2f}")

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.18**
# #### **Statement:**
#
# The College  Board's verbal and mathematics Scholastic Aptitude Tests are scored on a scale of 200 to 800. It seems reasonable to assume that the distribution of test scores are approximately normally distributed for both tests. Use the result from Exercise 1.17 to approximate the standard deviation for scores on the verbal test.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# The calculation is straightforward for the verbal test, the smallest value is 200 and the largest value is 800, then the range is 600. The approximation for the standard deviation is:
#
# \begin{align*}
# s \approx \frac{600}{4} = 150
# \end{align*}

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.19**
# #### **Statement:**
#
# According to the Environmental Protection Agency, chloroform, which in its gaseous form is suspected to be a cancer-causing agent, is present in small quantities in all the country's 240,000 public water sources. If the mean and standard deviation of the amounts of chloroform present in water sources are 34 and 53 micrograms per liter ($\mu\mathrm{g}/\mathrm{L}$), respectively, explain why chloroform amounts do not have a normal distribution.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 12)
#
# #### **Solution**
# **Theory Section:**
#
# From the theoretical approximation of percentage of measurements contained in intervals of a normal distribution, we can see that 95% of the values should be within the interval $\left[ -72, 140\right]$, this makes no sense since values smaller than 0 have no physical meaning.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.20**
# #### **Statement:**
#
# Weekly maintenance costs for a factory, recorded over a long period of time and adjusted for inflation, tend to have an approximately normal distribution with an average of $420 and a standard deviation of $30. If $450 is budgeted for next week, what is an approximate probability that this budgeted figure will be exceeded?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 13)
#
# #### **Solution**
# **Theory Section:**
#
# Since $\$450 = \bar{y} + s$ then the approximate probability contained from the point of $\bar{y}$ to $\bar{y} + s$ is half of that contained in the interval $\left[ \bar{y} - s, \bar{y} + s\right]$ which the empirical rule states it is $68\%/2 = 34\%$. Then the probability for the values contained in the interval $\left( -\infty, \bar{y} \right]$ is $50\%$. Finally the approximate probability that next's week budget will be bigger than $450\$$ is $1 - \left( 50\% + 34\% \right) = 16\%$.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.21**
# #### **Statement:**
#
# The manufacturer of a new food additive for beef cattle claims that $80\%$ of the animals fed a diet including this additive should have monthly weight gains in excess of 20 pounds. A large sample of measurements on weight gains for cattle fed this diet exhibits an approximately normal distribution with mean 22 pounds and standard deviation 2 pounds. Do you think the sample information contradicts the manufacturer's claim? (Calculate the probability of a weight gain exceeding 20 pounds.)
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 13)
#
# #### **Solution**
# **Theory Section:**
#
# Following the results from the previous exercise, there is an approximate probability of $34\%$ that a value lands in the interval $\left[\bar{y} - s, \bar{y}\right]$. Adding the $50\%$ probability for landing in the next interval, for this sample there is an $84\%$ chance of a weight gain of a cow exceeding 20 pounds, this is $5\%$ away from the claimed $80\%$ by the manufacturer, this sample doesn't contradict the manufacturer's claim.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.22**
# #### **Statement:**
#
# Prove that the sum of the deviations of a set of measurements about their mean is equal to zero; that is,
#
# \begin{align*}
# \sum_{i=1}^{n}\left( y_{i} - \bar{y} \right) = 0.
# \end{align*}
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 16)
#
# #### **Solution**
# **Theory Section:**
#
# First by distributing the sum over both $y_{i}$ and $\bar{y}$
#
# \begin{align*}
# \sum_{i=1}^{n}\left( y_{i} - \bar{y} \right) = \sum_{i=1}^{n}y_{i} - \sum_{i=1}^{n} \bar{y}
# \end{align*}
#
# Then, knowing that $n\bar{y} = \sum_{i=1}^{n}y_{i}$,
#
# \begin{align*}
# n\bar{y} - \sum_{i=1}^{n} \bar{y} = n\bar{y} - n\bar{y} = 0
# \end{align*}

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.23**
# #### **Statement:**
#
# The mean duration of television commercials is 75 seconds with standard deviation 20 seconds. Assume that the durations are approximately normally distributed to answer the following.
#
# 1. What percentage of commercials last longer than 95 seconds?
#
# 2. What percentage of the commercials last between 35 and 115 seconds?
#
# 3. Would you expect commercial to last longer than 2 minutes? Why or why not?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 16)
#
# #### **Solution**
# **Theory Section:**
#
# The first claim that can be done about the information contained in the exercise is: this information refers to the population of television commercials and not of a sample.
#
# 1. First note that $95 = \mu + \sigma$. From results of previous exercises, this gives us a probability of $34\%$ for the interval $\left[ \mu, \mu + \sigma \right]$. Then, in total the probability of a movie lasting less than $95$ seconds is $84\%$. Finally, the probability of a movie lasting more than 95 seconds is $100\% - 84\% = 16\%$.
#
# 2. For this exercise, first it can be shown that $35 \mathrm{s} = 75 \mathrm{s} - 3\left(20\mathrm{s}\right) = \mu - 3\sigma$, furthermore $115\mathrm{s} = 95 \mathrm{s} + 20\mathrm{s} = \mu + \sigma$. With the previous result, the interval of interest is $\left[\mu - 3\sigma, \mu + \sigma \right]$. Dividing the interval in two intervals, we get the probabilities:
#
#     - $\left[\mu - 3\sigma, 0 \right]$. From theory, this interval contains $ \frac{99.7\%}{2} = 49.85\%$ of all measurements.
#
#     - $\left[0, \mu + \sigma \right]$. From theory, this interval contains $\frac{68\%}{2} = 34\%$ of all measurements
#
#     Joining these intervals, we get the approximate percentage of measurements contained in it by adding both percentages. Approximately, $83.85\%$ of all measurements are contained in the interval $\left[\mu - 3\sigma, \mu + \sigma \right]$.
#
# 3. It is very unlikely that a value will land further than $135\mathrm{s}$, since this corresponds to $\mu + 3\sigma$. So it is safe to say that a commercial cannot be expected to last more than 2 minutes.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.24**
# #### **Statement:**
#
# Aqua running has been suggested as a method of cardiovascular conditioning for injured athletes and others who desire a low-impact aerobics program. In a study to investigate the relationship between exercise cadence and heart rate, the heart rates of 20 healthy volunteers were measured at a cadence of 48 cycles per minute (a cycle consisted of two steps). The data are as follows:
#
# <table class="borderless">
#   <tr>
#     <td>87</td><td>109</td><td>79</td><td>80</td><td>96</td><td>95</td><td>90</td><td>92</td><td>96</td><td>98</td>
#   </tr>
#   <tr>
#     <td>101</td><td>91</td><td>78</td><td>112</td><td>94</td><td>98</td><td>94</td><td>107</td><td>81</td><td>96</td>
#   </tr>
# </table>
#
# 1. Use the range of the measurements to obtain an estimate of the standard deviation.
#
# 2. Construct a frequency histogram for the data. Use the histogram to obtain a visual approximation to $\bar{y}$ and $s$.
#
# 3. Calculate $\bar{y}$ and $s$. Compare these results with the calculation checks provided by parts (1) and (2).
#
# 4. Construct the intervals $\bar{y} \pm ks$, $k = 1, 2,$ and $3$, and count the number of measurements falling in each interval. Compare the fractions falling in the intervals with the fractions that you would expect according to the empirical rule.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 16)
#
# #### **Solution**
# **Theory Section:**
#
# 1. The estimation of the standard deviation can be calculated using the methods of a pandas Series.
#
# 2. The histogram allows us to observe that the mean of this sample must be around 95 beats per minute, and the spread should be around 5 beats per minute.
#
# 3. The actual values for $\bar{y}$ and $s$ are calculated using the pandas Series methods. The approximation from part (1) of this exercise is close to the real value of $s$, the visual estimation for the value of $\bar{y}$ is close to the real value but the visual estimation of $s$ is almost half of the real value.
#
# 4. The intervals are calculated using a function and the desired values of $k$, since there are many values occurring at 80 bpm the standard deviation is large and the interval $\left[ \bar{y} - 2s, \bar{y} + 2s \right]$ contains $100\%$ of the measurements of this sample.
#
# **Code:**

# %%
raw_data = [87, 109, 79, 80, 96, 95, 90, 92, 96, 98,
            101, 91, 78, 112, 94, 98, 94, 107, 81, 96]

volunteer_vitals = pd.Series(raw_data, name = "heart_rate_per_48_cycles", dtype = "int64[pyarrow]")

# ==========================> Answer to 1. <===============================

approx_s = (volunteer_vitals.max() - volunteer_vitals.min())/4

print(f"The approximate standard deviation is {approx_s:.4f}.")
print()

# ==========================> Answer to 2. <===============================

fig, ax = plt.subplots()
sns.histplot(x = volunteer_vitals, stat = 'percent', bins = 10, ax = ax)
ax.set_title("Hear rates of 20 healthy volunteers at a cadence of 48 cycles per minute.")
ax.set_xlabel("Hear Rate")
ax.set_ylabel("Relative Frequency")
plt.show()

# ==========================> Answer to 3. <===============================

print(f"The mean of this sample is {volunteer_vitals.mean():.4f} bpm and the standard deviation is {volunteer_vitals.std():.4f} bpm.")
print()

# ==========================> Answer to 4. <===============================

def interval_percentage(data, m, s, k = 1):
    """
    This function finds the percentage of values that land in the value given by:
        [m - ks, m + ks]
    For m the mean and s the standard deviation of the data.
    """
    theory = [68, 95, 99.7]
    percentage = (data[ (data >= m - k*s) & (data <= m + k*s) ].count() ) / (data.count()) * 100
    print(f"The percentage of values that land in the interval [{m:.4f} - {k}({s:.4f}), {m:.4f} + {k}({s:.4f})] is {percentage:.2f}% vs the reported theory value of {theory[k-1]}")

for i in [1, 2, 3]:
    interval_percentage(volunteer_vitals, volunteer_vitals.mean(), volunteer_vitals.std(), i)

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.25**
# #### **Statement:**
#
# The following data give the lengths of time to failure  for $n = 88$ radio transmitter-receivers:
#
# <table class="borderless">
#   <tr>
#     <td>16</td><td>224</td><td>16</td><td>80</td><td>96</td><td>536</td><td>400</td><td>80</td>
#   </tr>
#   <tr>
#     <td>392</td><td>576</td><td>128</td><td>56</td><td>656</td><td>224</td><td>40</td><td>32</td>
#   </tr>
#   <tr>
#     <td>358</td><td>384</td><td>256</td><td>246</td><td>328</td><td>464</td><td>448</td><td>716</td>
#   </tr>
#   <tr>
#     <td>304</td><td>16</td><td>72</td><td>8</td><td>80</td><td>72</td><td>56</td><td>608</td>
#   </tr>
#   <tr>
#     <td>108</td><td>194</td><td>136</td><td>224</td><td>80</td><td>16</td><td>424</td><td>264</td>
#   </tr>
#   <tr>
#     <td>156</td><td>216</td><td>168</td><td>184</td><td>552</td><td>72</td><td>184</td><td>240</td>
#   </tr>
#   <tr>
#     <td>438</td><td>120</td><td>308</td><td>32</td><td>272</td><td>152</td><td>328</td><td>480</td>
#   </tr>
#   <tr>
#     <td>60</td><td>208</td><td>340</td><td>104</td><td>72</td><td>168</td><td>40</td><td>152</td>
#   </tr>
#   <tr>
#     <td>360</td><td>232</td><td>40</td><td>112</td><td>112</td><td>288</td><td>168</td><td>352</td>
#   </tr>
#   <tr>
#     <td>56</td><td>72</td><td>64</td><td>40</td><td>184</td><td>264</td><td>96</td><td>224</td>
#   </tr>
#   <tr>
#     <td>168</td><td>168</td><td>114</td><td>280</td><td>152</td><td>208</td><td>160</td><td>176</td>
#   </tr>
# </table>
#
# 1. Use the range to approximate $s$ for the $n = 88$ lengths of time to failure.
#
# 2. Construct a frequency histogram for the data. [Notice the tendency of the distribution to tail outward (Skew) to the right.]
#
# 3. Use a calculator (or computer) to calculate $\bar{y}$ and $s$. (Hand calculation is much too tedious for this exercise.)
#
# 4. Calculate the intervals $\bar{y} \pm ks$, $k = 1, 2$ and $3$, and count the number of measurements falling in each interval. Compare your results with the empirical rule results. Note that the empirical rule provides a rather food description of these data, even though the distribution is highly skewed.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 17)
#
# #### **Solution**
# **Theory Section:**
#
# 1. The calculation of the approximation of s is straightforward using a pandas Series to contain the data.
#
# 2. The histogram shows only values from 0 to about 700 following the principle that the measurements are made in time and negative time has no physical sense.
#
# 3. The calculation is straightforward using the methods of a pandas Series.
#
# 4. Using the function created in the previous example the percentages of measurements found in each of the intervals is found.
#
# **Code:**

# %%
raw_data = [16, 224, 16, 80, 96, 536, 400, 80,
            392, 576, 128, 56, 656, 224, 40, 32,
            358, 384, 256, 246, 328, 464, 448, 716,
            304, 16, 72, 8, 80, 72, 56, 608,
            108, 194, 136, 224, 80, 16, 424, 264,
            156, 216, 168, 184, 552, 72, 184, 240,
            438, 120, 308, 32, 272, 152, 328, 480,
            60, 208, 340, 104, 72, 168, 40, 152,
            360, 232, 40, 112, 112, 288, 168, 352,
            56, 72, 64, 40, 184, 264, 96, 224,
            168, 168, 114, 280, 152, 208, 160, 176]

transmitter_receivers_data = pd.Series(raw_data, name = "time_to_failure", dtype = "int64[pyarrow]")

# ==========================> Answer to 1. <===============================

print(f"The approximation of s using the range is {(transmitter_receivers_data.max() - transmitter_receivers_data.min()) / 4} units.")

# ==========================> Answer to 2. <===============================

fig, ax = plt.subplots()
sns.histplot(x = transmitter_receivers_data, stat = 'percent', bins = 15, ax = ax)
ax.set_title("Time of failure for n = 88 radio transmitter-receivers.")
ax.set_xlabel("Time")
ax.set_ylabel(r"Relative Frequency (\%)")
plt.show()

# ==========================> Answer to 3. <===============================

print(f"The mean of the distribution is {transmitter_receivers_data.mean():.4f} and the standard deviation is {transmitter_receivers_data.std():.4f} both in the units of measurement.")
print()

# ==========================> Answer to 4. <===============================

def interval_percentage(data, m, s, k = 1):
    """
    This function finds the percentage of values that land in the value given by:
        [m - ks, m + ks]
    For m the mean and s the standard deviation of the data.
    """
    theory = [68, 95, 99.7]
    percentage = (data[ (data >= m - k*s) & (data <= m + k*s) ].count() ) / (data.count()) * 100
    print(f"The percentage of values that land in the interval [{m:.4f} - {k}({s:.4f}), {m:.4f} + {k}({s:.4f})] is {percentage:.2f}% vs the reported theory value of {theory[k-1]}")

for i in [1, 2, 3]:
    interval_percentage(transmitter_receivers_data, transmitter_receivers_data.mean(), transmitter_receivers_data.std(), i)

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.26**
# #### **Statement:**
#
# Compare the ratio of the range to $s$ for the three sample sizes ($n = 6$, $20$, and $88$) for Exercises 1.12, 1.24, and 1.25. Note that the ratio tends to increase as the amount of data increases. The greater the amount of data, the greater will be their tendency to contain a few extreme values that will inflate the range and have relatively little effect on $s$. We ignored this phenomenon and suggested that you use $4$ as the ratio for finding a guessed value of $s$ in checking calculations.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 17)
#
# #### **Solution**
# **Theory Section:**
#
# The approximations of $s$ in the mentioned exercises are:
#
# - **Exercise 1.12**. For this exercise the approximation using the range is $0.75$ and $s = 1.2111$, the range is $3$. The ratio of the range to $s$ is $\frac{R}{s} = 2.4772$.
#
# - **Exercise 1.24**. For this exercise the approximation using the range is $8.5$ and $s = 9.5537$, the range is $34$. The ratio of the range to $s$ is $\frac{R}{s} = 3.5588$.
#
# - **Exercise 1.25**. For this exercise the approximation using the range is $177$ and $s = 162.1728$, the range is $34$. The ratio of the range to $s$ is $\frac{R}{s} = 4.3657$.
#
# **Code:**

# %%
def range_comparison(data):
    """
    Function that compares the ratio of the range to the standard deviation.
    """
    print(f"s = {np.std(data, ddof = 1):.4f}.", f" The range is {max(data) - min(data)}.")
    print(f"The ratio of range to s is {(max(data) - min(data))/np.std(data, ddof = 1):.4f}.")
    print()


# Ratio for Exercise 1.12
data_1_12 = [1, 4, 2, 1, 3, 3]
range_comparison(data_1_12)

# Ratio for Exercise 1.24
data_1_24 = [87, 109, 79, 80, 96, 95, 90, 92, 96, 98,
            101, 91, 78, 112, 94, 98, 94, 107, 81, 96]
range_comparison(data_1_24)

# Ratio for Exercise 1.25
data_1_25 = [16, 224, 16, 80, 96, 536, 400, 80,
            392, 576, 128, 56, 656, 224, 40, 32,
            358, 384, 256, 246, 328, 464, 448, 716,
            304, 16, 72, 8, 80, 72, 56, 608,
            108, 194, 136, 224, 80, 16, 424, 264,
            156, 216, 168, 184, 552, 72, 184, 240,
            438, 120, 308, 32, 272, 152, 328, 480,
            60, 208, 340, 104, 72, 168, 40, 152,
            360, 232, 40, 112, 112, 288, 168, 352,
            56, 72, 64, 40, 184, 264, 96, 224,
            168, 168, 114, 280, 152, 208, 160, 176]
range_comparison(data_1_25)

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.27**
# #### **Statement:**
#
# A set of 340 examination scores exhibiting a bell-shaped relative frequency distribution has a mean of $\bar{y} = 72$ and a standard deviation of $s = 8$. Approximately how many of the scores would you expect to fall in the interval from 64 to 80? The interval from 56 to 88?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 17)
#
# #### **Solution**
# **Theory Section:**
#
# This exercise is straightforward to solve using theory. The interval of $\left[ 64, 80 \right]$ corresponds to $\left[ \bar{y} - s, \bar{y} + s \right]$, from theory one can expect that $68\%$ of measurements are found in this interval. The interval of $\left[ 56, 88 \right]$ corresponds to the interval $\left[ \bar{y} - 2s, \bar{y} + 2s \right]$, from theory one can expect that $95\%$ of measurements are found in this interval.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.28**
# #### **Statement:**
#
# The discharge of suspended solids from a phosphate mine is normally distributed with mean daily discharge 27 miligrams per liter (mg/L) and standard deviation 14 mg/L. In what proportion of the days will the daily discharge be less than 13 mg/L?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 17)
#
# #### **Solution**
# **Theory Section:**
#
# The interval $\left[ 13, 41 \right]$ corresponds to the interval $\left[ \bar{y} - s, \bar{y} + s \right]$ which contains approximately $68\%$ of measurements. The interval $\left( - \infty, \bar{y} \right]$ contains $50\%$ of measurements, the measurements contained in the interval $\left( - \infty, \bar{y} - s \right]$ contains $50\% - \frac{68}{2}\% = 16\%$ measurements approximately.
#
# **Code:**

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.29**
# #### **Statement:**
#
# A machine produces bearings with mean diameter $3.00$ inches and standard deviation 0.01 inch. Bearings with diameters in excess of $3.02$ inches or less than $2.98$ inches will fail to meet quality specifications.
#
# 1. Approximately what fraction of this machine's production will fail to meet specifications?
#
# 2. What assumptions did you make concerning the distribution of bearing diameters in order to answer this question?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18)
#
# #### **Solution**
# **Theory Section:**
#
# 1. Since the interval that meet quality specifications are inside the interval $\left[ 2.98, 3.02 \right]$ which corresponds to the interval $\left[ \bar{y} - 2s, \bar{y} + 2s \right]$ in terms of $\bar{y}$ and $s$, it's expected that approximately $95\%$ of measurements are contained inside this interval, then approximately $5\%$ of measurements will fail to meet specifications.
#
# 2. The assumption that had to be made is that the distribution is normal.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.30**
# #### **Statement:**
#
# Compared to their stay-at-home peers, women employed outside the home have higher levels of high-density lipoproteins (HDL), the "good" cholesterol associated with lower risk of heart attacks. A study of cholesterol levels in 2000 women, aged 25-64, living in Augsburg, Germany, was conducted by Ursula Haertel, Ulrigh Keil, and colleagues at the GSF-Medis Institut in Munich. Of these 2000 women, the $48\%$ who worked outside the home had HDL levels that were between $2.5$ and $3.6$ miligrams per deciliter (mg/dL) higher than the HDL levels of their stay-at-home counterparts. Suppose that the difference in HDL levels is normally distributed, with mean 0 (indicating no difference between the two groups of women) and standard deviation 1.2 mg/dL. If you were to select an employed woman and a stay-at-home counterpart at random, what is the probability that the difference in their HDL levels would be between 1.2 and 2.4?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 17, 18)
#
# #### **Solution**
# **Theory Section:**
#
# First the statement that there are $48\%$ of measurements inside the interval $\left[ 2.5, 3.6 \right]$ is incorrect, given that this is a normal distribution $\bar{y} + 2s < 2.5$. From the theoretical approximation, the percentage of measurements found in the interval $\left[ \bar{y} + 2s, \infty \right)$ is $2.5\%$, so the stated percentage of $48\%$ of measurements for the interval $\left[ 2.5, 3.6 \right]$, which is a subset of $\left[ \bar{y} + 2s, \infty \right)$ contradicts both theory and reason. Using python in the code section we find the value found in a generated random normal sample of 2000 values and the probability for a population distribution with the mentioned parameters.
#
# To find the probability that a measurement falls in the interval $\left[ 1.2, 2.4 \right]$ we can use 3 different methods.
#
# - Using the theoretical approximation, the interval $\left[ 1.2, 2.4 \right]$ corresponds to the interval $\left[ \bar{y} + s, \bar{y} + 2s \right]$ which corresponds to a probability of $\frac{95 - 86}{2}\% = 13.5 \%$.
#
# - Using the `cdf()` function from the `norm` module of `scipy.stats` for the interval $\left[ 1.2, 2.4 \right]$ we find that the probability is approximately $15\%$.
#
# - Using the results of the random sample, the percentage of measurements that fall in the interval $\left[ 1.2, 2.4 \right]$ is $2.4 \%$.
#
# The sample will not yield reliable values for a probability, the theoretical approximation and the actual calculation of the cumulative distribution function is the right way to find the probability (this cdf concept will become clear in further chapters).
#
# **Code:**

# %%
# Generate random normal sample with parameters
# This is a cell on its own to avoid regenerating the values again

women_hdl_sample = pd.Series(norm.rvs(0, 1.2, size = 2000), name = "hdl_difference", dtype = "float64" )

fg_hdl = sns.displot(women_hdl_sample, binwidth = 0.25, stat = "percent")
fg_hdl.set_axis_labels("HDL Difference (mg/L)", "Percent of Measurements")
fg_hdl.ax.set_title("Frequency of HDL difference for artificial sample of 2000 women.")
plt.show()

percentage_of_sample_measurements_2_5__3_6 = (women_hdl_sample[ (women_hdl_sample >= 2.5) & (women_hdl_sample <= 3.6)].count() / women_hdl_sample.count()) * 100
prob_2_5__3_6 = (norm.cdf( 3.6, loc = 0, scale = 1.2) - norm.cdf(2.5, loc = 0, scale = 1.2))*100

print(f"For this randomly generated sample the mean is {women_hdl_sample.mean():.4f} and the standard deviation is {women_hdl_sample.std():.4f} and the percentage of measurements of this sample in the interval  [2.5, 3.6] is {percentage_of_sample_measurements_2_5__3_6:.4f} %.")
print(f"For a normal distribution with population mean 0 mg/L and standard deviation 1.2 mg/L, the probability for the interval [2.5, 3.6] is {prob_2_5__3_6:.4f} %.")
print()


prob_1_2__2_4 = (norm.cdf(2.4, loc = 0, scale = 1.2) - norm.cdf(1.2, loc = 0, scale = 1.2)) * 100
percentage_of_sample_measurements_1_2__2_4 = (women_hdl_sample[ (women_hdl_sample >= 2.5) & (women_hdl_sample <= 3.6)].count() / women_hdl_sample.count()) * 100
print(f"Using the normal distribution of a population, the probability that a measurement is in the interval [1.2, 2.4] is {prob_1_2__2_4:.4f} %.")
print(f"For this dataset of 2000 measurements, the probability that a measurement is in the interval [1.2, 2.4] is {percentage_of_sample_measurements_1_2__2_4:.4f} %.")

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.31**
# #### **Statement:**
#
# Over the past year, a fertilizer production process has shown an average daily yield of 60 tons with a variance in daily yields of 100. If the yield should fall to less than 40 tons tomorrow, should this result cause you to suspect an abnormality in the process? (Calculate the probability of obtaining less than 40 tons.) What assumptions did you make concerning the distribution of yields?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18)
#
# #### **Solution**
# **Theory Section:**
#
# First, the parameters we are given can be taken as concerning the population, using the fact that the variance is $\sigma^{2}$, the standard deviation of this population is $\sigma = \sqrt{\sigma^{2}} = \sqrt{100} = 10$. Without any more information on the process, the daily yields of fertilizer productions can be assumed to be normally distributed. A daily yield lower than 40 is below the value $\mu - 2\sigma$, then, using the theoretical approximation, a daily production yield in the interval $\left[ - \infty, \mu - 2\sigma \right]$ has a probability of approximately $2.5\%$ of occurring.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.32**
# #### **Statement:**
#
# Let $k \geq 1$. Show that, for any set of $n$ measurements, the fraction included in the interval $\bar{y} - ks$ to $\bar{y} + ks$ is at least $\left( 1 - 1/k^{2} \right)$. [*Hint*: $$ s^{2} = \frac{1}{n-1} \left[ \sum_{i = 1}^{n}(y_{i} - \bar{y})^{2} \right].$$ In this expression, replace all deviations for which $|y_{i} - \bar{y}| \geq  ks$ with $ks$. Simplify.] This result is known as *Tchebysheff's theorem*.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18)
#
# #### **Solution**
# **Theory Section:**
#
# First, define the sets:
#
# - $A := \left\{i \; | \; |y_{i} - \bar{y}| < ks \right\}$
#
# - $B := \left\{i \; | \; |y_{i} - \bar{y}| \geq ks \right\}$
#
# Set $A$ contains the values of $i$ where $y_{i}$ belongs to the interval $\left( \bar{y} - ks, \bar{y} + ks \right)$. The set $B$ contains the values of $i$ where $y_{i}$ belongs to the interval $\left( -\infty, \bar{y} - ks \right] \cup \left[ \bar{y} + ks, \infty  \right)$. Then,
#
# \begin{align*}
# s^{2} =& \frac{1}{n-1} \left[ \sum_{i=1}{n}\left( y_{i} - \bar{y} \right)^{2} \right] \\
# \\
# =& \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + \sum_{i \in B}\left( y_{i} - \bar{y} \right)^{2} \right].
# \end{align*}
#
# Given that $|y_{i} - \bar{y}|\geq ks \; \; \Rightarrow \; \; (y_{i} - \bar{y})^{2} \geq (ks)^{2} $. This gives
#
# \begin{align*}
# s^{2} = \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + \sum_{i \in B}\left( y_{i} - \bar{y} \right)^{2} \right] \geq & \; \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + \sum_{i \in B}\left( ks \right)^{2} \right]
# \end{align*}
#
# By transitivity of inequalities its found that
#
# \begin{align*}
# s^{2} \geq & \; \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + \sum_{i \in B}\left( ks \right)^{2} \right]
# \end{align*}
#
# The cardinality of $A$ and $B$ is $|A|$ and $|B|$, then
#
# \begin{align*}
# \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + \sum_{i \in B}\left( ks \right)^{2} \right] = \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + |B|\left( ks \right)^{2} \right]
# \end{align*}
#
# Knowing that for every $i$ in $A$, $(y_{i} - \bar{y}) ^{2} \geq 0$, then it follows that
#
# \begin{align*}
# s^{2} \geq \frac{1}{n-1}\left[ \sum_{i \in A}\left( y_{i} - \bar{y} \right)^{2} + |B|\left( ks \right)^{2} \right] \geq \frac{1}{n-1}|B|\left( ks \right)^{2}
# \end{align*}
#
# Now, given that $|B| = n - |A|$,
#
# \begin{align*}
# s^{2} \geq & \; \frac{1}{n-1}|B|\left( ks \right)^{2} \\
# \\
# \frac{n - 1}{k^{2}} \geq & \; |B| \\
# \\
# \frac{n - 1}{k^{2}} \geq & \; n -  |A| \\
# \\
# \frac{|A|}{n} \geq & \; 1 + \frac{1}{k^{2}n} - \frac{1}{k^{2}}
# \end{align*}
#
# Finally, with $\frac{1}{k^{2}n} \geq 0$
#
# \begin{align*}
# \frac{|A|}{n} \geq & \; 1 - \frac{1}{k^{2}}
# \end{align*}
#
# Here, $|A|/n$ is the fraction of values inside the interval $\left( \bar{y} - ks, \bar{y} + ks \right)$, it has $1 - 1/k^{2}$ as a lower bound.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.33**
# #### **Statement:**
#
# A personnel manager for a certain industry has record of the number of employees absent per day. The average number absent is $5.5$, and the standard deviation is $2.5$. Because there are many days with zero, one, or two absent and only a few with more than ten absent, the frequency distribution is highly skewed. The manager wants to publish an interval in which at least $75\%$ of these values lie. Use the result in Exercise 1.32 to find such an interval.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18)
#
# #### **Solution**
# **Theory Section:**
#
# Here $75\%$ of values is the proportion $0.75$ of all values, using the result from the previous exercise
#
# \begin{align*}
# \frac{|A|}{n} \geq 1 - \frac{1}{k^{2}}
# \end{align*}
#
# $k$ is in days. We are looking for the value of $k$ for which $\frac{|A|}{n} = 0.75$, as seen in the graph of the code section this is the intersection of the horizontal line at 0.75 and the function $f(k) =1-\frac{1}{k^{2}}$. Then, to find the value of $k$ that is the lower bound of the interval for which $\frac{|A|}{n} \geq 0.75$, the inequality is set to be
#
# \begin{align*}
# 1 - \frac{1}{k^{2}} \geq 0.75
# \end{align*}
#
# Then
#
# \begin{align*}
# k \geq \sqrt{\frac{1}{1 - 0.75}} = 2
# \end{align*}
#
# The lower bound for $k$ is $2$. Then the interval to publish is $\left[ 0.5, 10.5 \right]$.
#
# **Code:**

# %%
# Ilustration of the lower bound.

k = np.linspace(1, 10, 500)
f_k = 1 - (1/(k*k))

fig, ax = plt.subplots()

sns.lineplot(x = k, y = f_k, ax = ax, label = r"$1 - \frac{1}{k^{2}}$" )
ax.hlines(0.75, xmin = 1, xmax = 10, color = "red", label = "Least proportion.")
ax.axvline(4, color = "red",linestyle = "--", label = r"Lower bound for $k$")

ax.set_xlabel("k")
ax.set_ylabel("Proportion")
fig.suptitle(r"$1 - \frac{1}{k^{2}}$ vs k")
ax.legend()
plt.show()

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.34**
# #### **Statement:**
#
# For the data discussed in Exercise 1.33, give an upper bound to the fraction of days when there are more than 13 absentees.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18)
#
# #### **Solution**
# **Theory Section:**
#
# First, find a $k$ such that the interval $\left( 13 , \infty \right)$ is expressed in terms of k. Using the expression $13 = 5.5 + k(2.5)$, then, $k = \frac{13 - 5.5}{2.5} = 3$, this means that a day with 13 absentees is 3 times the standard deviation from the mean. By Tchebysheff's theorem, the fraction contained inside the interval is
#
# \begin{align*}
# \frac{|A|}{n} \geq & \; 1 - \frac{1}{k^{2}} \\
# \\
# \frac{|A|}{n} \geq & \; 1 - \frac{1}{3^{2}} \\
# \\
# \frac{|A|}{n} \geq & \; \frac{8}{9}
# \end{align*}
#
# By definition, $\frac{|A|}{n} = 1 - \frac{|B|}{n}$,
#
# \begin{align*}
# 1 - \frac{|B|}{n} \geq & \; \frac{8}{9}\\
# \\
# \frac{|B|}{n} \leq & \; 1 - \frac{8}{9}\\
# \\
# \frac{|B|}{n} \leq & \; \frac{1}{9}
# \end{align*}
#
# This means that at most 1/9 of the days can have 13 or more absentees.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.35**
# #### **Statement:**
#
# A pharmaceutical company wants to know whether an experimental drug has an effect on systolic blood pressure. Fifteen randomly selected subjects were given the drug and, after sufficient time for the drug to have an impact, their systolic blood pressures were recorded. The data appear below:
#
# <table class="borderless">
#   <tr>
#     <td>172</td><td>140</td><td>123</td><td>130</td><td>115</td>
#   </tr>
#   <tr>
#     <td>148</td><td>108</td><td>129</td><td>137</td><td>161</td>
#   </tr>
#   <tr>
#     <td>123</td><td>152</td><td>133</td><td>128</td><td>142</td>
#   </tr>
# </table>
#
# 1. Approximate the value of $s$ using the range approximation.
#
# 2. Calculate the values of $\bar{y}$ and $s$ for the 15 blood pressure readings.
#
# 3. Use Tchebysheff's theorem (Exercise 1.32) to find values $a$ and $b$ such that at least $75\%$ of the blood pressure measurements lie between $a$ and $b$.
#
# 4. Did Tchebysheff's theorem work? That is, use the data to find the actual percent of blood pressure readings that are between the values $a$ and $b$ you found in part (3). Is this actual percentage greater than $75\%$?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18)
#
# #### **Solution**
# **Theory Section:**
#
# 1. The range approximation for $s$ states that the $s$ of a set of measurements may be roughly approximated by one-fourth of the range. This is by taking the largest and smallest value from the blood pressure recordings and finding the range
# \begin{align*}
# s \approx \frac{\mathrm{range}}{4} = \frac{172 - 108}{4} = 16
# \end{align*}
#
# 2. By finding the values using pandas it can be seen that $\bar{y} = 136.0667$ and $s=17.1025$.
#
# 3. To find the values $a$ and $b$ for which at least $75\%$ of the measurements are, that is $\frac{|A|}{n} \geq 0.75$, we use the result of exercise 1.32
#
#     \begin{align*}
#     0.75 & \leq 1 - \frac{1}{k^{2}} \\
#     1 - 0.75 & \geq \frac{1}{k^{2}} \\
#     k & \geq \sqrt{\frac{1}{1 - 0.75}} \\
#     k & \geq 2
#     \end{align*}
#
#     $k$ has to be at least 2. Then, one can find the  values $a = \bar{y} - ks = 101.8617$ and $b = \bar{y} + ks = 170.2717$. The interval that contains at least $75\%$ of the measurements is $\left[101.8617, 170.2717 \right]$.
#
# 4. Using a python script and filtering the data frame one can find that $93.33\%$ of the values are inside this interval which is larger than $75\%$ the least proportion of values that should be found.
#
# **Code:**

# %%
# ==========================> Answer to 2. <===============================

raw_data = [172, 140, 123, 130, 115,
            148, 108, 129, 137, 161,
            123, 152, 133, 128, 142]

blood_pressures = pd.Series(raw_data, name="blood_pressure", dtype = "float64[pyarrow]")

print(f"The mean of the measurements is {blood_pressures.mean():.4f} and the standard deviation is {blood_pressures.std():.4f} both in the units of measurement.")

# ==========================> Answer to 4. <===============================

true_fraction = blood_pressures[(blood_pressures >= 101.8617) & (blood_pressures <= 170.2717)].count()/blood_pressures.count()

print(f"The amount of values that are inside is {true_fraction * 100:.4f} %.")

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.36**
# #### **Statement:**
#
# A random sample of 100 foxes was examined by a team of veterinarians to determine the prevalence of a specific parasite. Counting the number of parasites of this specific type, the veterinarians found that 69 foxes had no parasites of the type of interest, 17 had one parasite of the type under study, and so on. A summary of their results is given in the following table
#
# <center><img src="im5.png" alt="im5" width="400px"/></center>
#
# 1. Construct the relative frequency histogram for the number of parasites per fox.
#
# 2. Calculate $\bar{y}$ and $s$ for the data given.
#
# 3. What fraction of the parasite counts falls within 2 standard deviations of the mean? Within 4 standard deviations? Do your results agree with Tchebysheff's theorem (exercise 1.32) and/or the empirical rule?
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 18, 19)
#
# #### **Solution**
# **Theory Section:**
#
# To solve this, some python implementation is necessary.
#
# 1. Below is the code to implement the histogram for the given prevalence of parasites.
#
# 2. Using pandas vectorization it can be found that $\bar{y} = 0.66& and $s = 1.3870$.
#
# 3. First, using pandas it can be found that for the interval $\left[ 0, 3.434 \right]$ the fraction of values that fall within this interval is 0.95. (the left limit is 0 since $\bar{y}-2s = -2.114$ has no meaning for this problem). For Tchebysheff's theorem we have that $k=2$, then $1 - 1/2^{2} = 0.75$ which is correct, at least, the fraction 0.75 of the measurements is between $\left[ 0, 3.434 \right]$, then the empirical rule means that $95\%$ of values is contained in this interval which is also correct, but for this kind of distribution it makes no sense.
#
# **Code:**

# %%
# ==========================> Answer to 1. <===============================

raw_data = [69, 17, 6, 3, 1, 2, 1, 0, 1]

parasites_series = pd.Series(raw_data, name = "number_of_parasites", dtype = "float64[pyarrow]")
parasites_series_relative_frequency = parasites_series / parasites_series.sum() * 100

fig, ax = plt.subplots()
sns.barplot(x = parasites_series_relative_frequency.index, y = parasites_series_relative_frequency, ax = ax)
#parasites_series_relative_frequency.plot.bar(ax = ax, rot = 0)
ax.set_title("Relative Frequency for the Prevalence of a Specific Parasite in Foxes")
ax.set_xlabel("Number of Parasites")
ax.set_ylabel("Relative Frequency")
plt.show()

# ==========================> Answer to 2. <===============================

mean_parasites = (parasites_series.index * parasites_series).sum() / parasites_series.sum()
std_parasites  = np.sqrt((parasites_series * ((parasites_series.index - mean_parasites) ** 2) ).sum() / (parasites_series.sum() - 1))
print(f"The mean is {mean_parasites:.4f} and the standard deviation is {std_parasites:.4f}")

# ==========================> Answer to 3. <===============================

fraction_2s_parasites = parasites_series[(parasites_series.index >= 0) & (parasites_series.index <= 3.434)].sum() / parasites_series.sum()
print(f"The fraction of values that fall in the interval [0, 3.434] is {fraction_2s_parasites:.4f}.")

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.37**
# #### **Statement:**
#
# Studies indicate that drinking water supplied by some old lead-lined city piping systems may contain harmful levels of lead. Based on data presented by Karalekas and colleagues, it appears that the distribution of lead content readings for individual water specimens has mean $0.33 \mathrm{mg}/\mathrm{L}$ and standard deviation $.10\mathrm{mg}/\mathrm{L}$. Explain why is it obvious that the lead content readings are *not* normally distributed.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 19)
#
# #### **Solution**
# **Theory Section:**
#
# A normal distribution can follow the empirical rule of $68\%$, $95\%$ and $99.5\%$. In this case, when evaluating the interval for $68\%$ of measurements, $\left[ \bar{y} - s, \bar{y} + s \right]$, we get to $\left[ -0.067, 0.133 \right]$ which for the left limit makes no physical sense since a concentration has to be positive.

# %% [markdown]
# <style>
#   table.borderless {
#     border-collapse: collapse;  /* Colapse adjacent cells borders */
#     border-spacing: 0;          /* Delete spacing between cells */
#   }
#   table.borderless td {
#     border: none;               /* Removes any visible border */
#     padding: 4px 8px;           /* Optional internal space for visualization */
#   }
# </style>
#
# <style>
#   table.linetop-borderless {
#     border-collapse: collapse;
#     border-spacing: 0;
#     margin-top: 1em;
#   }
#   table.linetop-borderless th,
#   table.linetop-borderless td {
#     border: none;
#     padding: 4px 8px;
#     text-align: right;
#   }
#   table.linetop-borderless th {
#     font-weight: bold;
#     text-align: left;
#   }
# </style>
#
# ### **Exercise 1.38**
# #### **Statement:**
#
# In Exercise 1.19, the mean and standard deviation of the amount of chloroform present in water sources were given to be 34 and 53, respectively. You argued that the amounts of chloroform could therefore not be normally distributed. Use Tchebysheff's theorem (Exercise 1.32) to describe the distribution of chloroform amounts in water sources.
#
# (Wackerly, Mendenhall & Scheaffer, 2008, p. 19)
#
# #### **Solution**
# **Theory Section:**
#
# Using Tchebysheff's theorem, for $k = 1$, $1 - 1/1^{2} = 0$, which means that at least $0\%$ of measurements are in the interval $\left[0, 87\right]$. Then for $k = 2$, $1 - 1/2^{2} = 0.75$, which means that at least $75\%$ of measurements are in the interval $\left[0, 140\right]$. Finally, for $k = 3$, $1 - 1/3^{2} = 0.8889$, which means that at least $88.89\%$ of measurements are in the interval $\left[0, 193\right]$.
#
#
# **Code:**

# %% [markdown]
# ## Chapter conclusions
#
# - **What patterns are observed.** In this chapter the most observed patterns are the calculations of mean and standard deviation for samples, the use of the empirical rule as a good estimator for experiments on a normal distribution and the use of graphical tools like the histogram to visualize the arrangement of data through the set of possible outcomes.
#
# - **What techniques are repeated?** The plotting of relative frequency histograms, the use of the empirical rule for normal distributions to estimate the values in which a proportion of measurements from an experiment can be found and the stronger Tchebysheff's theorem to establish a better estimation.
#
# - **What python tools where useful?** Pandas and numpy are python packages that contain great statistical tools that allow for a fast, easy and understandable process of exploratory data analysis. In particular the pandas Series for a single type of value observed in measurements and the methods implemented for Series.
#
# ## References
#
# - Wackerly, D. D., Mendenhall III, W., & Scheaffer, R. L. (2008). *Mathematical Statistics with Application*s (7ª ed.). Cengage Learning.
# - Official numpy, scipy, matplotlib, pandas documentation.
